# %%
import numpy as np
from sklearn.datasets import make_blobs
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
# %matplotlib inline

def linear_plot(X, y, w=None, b=None):
    
    mycolors = {"blue": "steelblue", "red": "#a76c6e", "green": "#6a9373"}
    colors = [mycolors["red"] if yi==1 else mycolors["blue"] for yi in y]
    
    # Plot data 
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,8))
    ax.scatter(X[:,0], X[:,1], color=colors, s=150, alpha=0.95, zorder=2)
    
    # Plot boundaries 
    lower_left = np.min([np.min(X[:,0]), np.min(X[:,1])])
    upper_right = np.max([np.max(X[:,0]), np.max(X[:,1])])
    gap = .1*(upper_right-lower_left)
    xplot = np.linspace(lower_left-gap, upper_right+gap, 20)
    if w is not None and b is not None: 
        ax.plot(xplot, (-b - w[0]*xplot)/w[1], color="gray", lw=2, zorder=1)
        ax.plot(xplot, ( 1 -b - w[0]*xplot)/w[1], color="gray", lw=2, ls="--", zorder=1)
        ax.plot(xplot, (-1 -b - w[0]*xplot)/w[1], color="gray", lw=2, ls="--", zorder=1)
        
    
    ax.set_xlim([lower_left-gap, upper_right+gap])
    ax.set_ylim([lower_left-gap, upper_right+gap])
    
    ax.grid(alpha=0.25)
    
def part2data():
    
    np.random.seed(1239)
    
    X = np.zeros((22,2))
    X[0:10,0]  = 1.5*np.random.rand(10) 
    X[0:10,1]  = 1.5*np.random.rand(10)
    X[10:20,0] = 1.5*np.random.rand(10) +  1.75
    X[10:20,1] = 1.5*np.random.rand(10) +  1
    X[20,0] = 1.5
    X[20,1] = 2.25
    X[21,0] = 1.6
    X[21,1] = 0.25
    
    y = np.ones(22)
    y[10:20] = -1 
    y[20] = 1
    y[21] = -1
    
    return X, y

def part3data(N=100, seed=1235):
    
    np.random.seed(seed)
    
    X = np.random.uniform(-1,1,(N,2))
    y = np.array([1 if y-x > 0 else -1 for (x,y) in zip(X[:,0]**2 * np.sin(2*np.pi*X[:,0]), X[:,1])])
    X = X + np.random.normal(0,.1,(N,2))
    
    return X, y

def nonlinear_plot(X, y, clf=None): 
    
    mycolors = {"blue": "steelblue", "red": "#a76c6e", "green": "#6a9373"}
    
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,10))
    
    colors = [mycolors["red"] if yi==1 else mycolors["blue"] for yi in y]
    ax.scatter(X[:,0],X[:,1], marker='o', color=colors, s=100, alpha=0.5)
    
    ax.arrow(-1.25,0,2.5,0, head_length=0.05, head_width=0.05, fc="gray", ec="gray", lw=2, alpha=0.25)
    ax.arrow(0,-1.25,0,2.5, head_length=0.05, head_width=0.05, fc="gray", ec="gray", lw=2, alpha=0.25)
    z = np.linspace(0.25,3.5,10)
    
    ax.set_xlim([-1.50,1.50])
    ax.set_ylim([-1.50,1.50])
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    plt.xticks([], fontsize=16)
    plt.yticks([], fontsize=16)
    

    if clf: 
        
        clf.fit(X,y)

        x_min = X[:, 0].min()+.00
        x_max = X[:, 0].max()-.00
        y_min = X[:, 1].min()+.00
        y_max = X[:, 1].max()-.00

        colors = [mycolors["red"] if yi==1 else mycolors["blue"] for yi in y]

        XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
        Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

        # Put the result into a color plot
        Z = Z.reshape(XX.shape)
        plt.contour(XX, YY, Z, colors=[mycolors["blue"], "gray", mycolors["red"]], linestyles=['--', '-', '--'],
                    levels=[-1.0, 0, 1.0], linewidths=[2,2,2], alpha=0.9)
    

class MidpointNormalize(Normalize):

    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))
    
def plotSearchGrid(grid):
    
    scores = [x for x in grid.cv_results_["mean_test_score"]]
    scores = np.array(scores).reshape(len(grid.param_grid["C"]), len(grid.param_grid["gamma"]))

    plt.figure(figsize=(10, 8))
    plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
    plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot,
               norm=MidpointNormalize(vmin=0.2, midpoint=0.92))
    plt.xlabel('gamma')
    plt.ylabel('C')
    plt.colorbar()
    plt.xticks(np.arange(len(grid.param_grid["gamma"])), grid.param_grid["gamma"], rotation=45)
    plt.yticks(np.arange(len(grid.param_grid["C"])), grid.param_grid["C"])
    plt.title('Validation accuracy')
    plt.show()

from IPython.core.display import HTML
HTML("""
<style>
.MathJax nobr>span.math>span{border-left-width:0 !important};
</style>
""")
# Out:
# <style>
# .MathJax nobr>span.math>span{border-left-width:0 !important};
# </style>

# %%
X, y = part2data()
linear_plot(X, y)

# %%
from sklearn.svm import LinearSVC

# TODO: Build a LinearSVC model called lsvm. Train the model and get the parameters
lsvm = LinearSVC(C=1.0, loss='hinge').fit(X, y)


# use this code to plot the resulting model
w = lsvm.coef_[0]
b = lsvm.intercept_
print(w,b)
linear_plot(X, y, w=w, b=b)
# Out:
# [-1.41897528  0.30584252] [1.76759606]

# %%
X, y = part3data(N=300, seed=1235)
nonlinear_plot(X, y)

# %%
from sklearn.svm import SVC

nlsvm= SVC(C=1.0, kernel='rbf', gamma='auto').fit(X, y)


nonlinear_plot(X, y, nlsvm)

# %%
from sklearn.model_selection import cross_val_score


nlsvm =SVC(C=1.0, kernel='rbf', gamma=1).fit(X, y)
scores= cross_val_score(nlsvm, X, y)
print("cross-val mean-accuracy: {:.3f}".format(np.mean(scores)))
nonlinear_plot(X, y, nlsvm)

# C tuning

for i in range(1, 30):
    svm = SVC(C = i, kernel ='rbf', gamma = 'auto').fit(X,y)
    scores = cross_val_score(svm, X, y)
    print(f"C = {i}"" cross-val mean-accuracy: {:.3f}".format(np.mean(scores)))

# gamma tuning
gamma_values = [0.001, 0.01, 0.1, 1, 10, 100]
for gamma in gamma_values:
    svm = SVC(C=4, kernel='rbf', gamma=gamma).fit(X, y)
    scores = cross_val_score(svm, X, y)
    print(f"gamma = {gamma} cross-val mean-accuracy: {np.mean(scores):.3f}")
# Out:
# cross-val mean-accuracy: 0.920
# C = 1 cross-val mean-accuracy: 0.920
# C = 2 cross-val mean-accuracy: 0.923
# C = 3 cross-val mean-accuracy: 0.920
# C = 4 cross-val mean-accuracy: 0.930
# C = 5 cross-val mean-accuracy: 0.927
# C = 6 cross-val mean-accuracy: 0.927
# C = 7 cross-val mean-accuracy: 0.927
# C = 8 cross-val mean-accuracy: 0.930
# C = 9 cross-val mean-accuracy: 0.927
# C = 10 cross-val mean-accuracy: 0.927
# C = 11 cross-val mean-accuracy: 0.927
# C = 12 cross-val mean-accuracy: 0.927
# C = 13 cross-val mean-accuracy: 0.927
# C = 14 cross-val mean-accuracy: 0.927
# C = 15 cross-val mean-accuracy: 0.923
# C = 16 cross-val mean-accuracy: 0.923
# C = 17 cross-val mean-accuracy: 0.923
# C = 18 cross-val mean-accuracy: 0.923
# C = 19 cross-val mean-accuracy: 0.923
# C = 20 cross-val mean-accuracy: 0.923
# C = 21 cross-val mean-accuracy: 0.923
# C = 22 cross-val mean-accuracy: 0.920
# C = 23 cross-val mean-accuracy: 0.920
# C = 24 cross-val mean-accuracy: 0.920
# C = 25 cross-val mean-accuracy: 0.920
# C = 26 cross-val mean-accuracy: 0.920
# C = 27 cross-val mean-accuracy: 0.920
# C = 28 cross-val mean-accuracy: 0.920
# C = 29 cross-val mean-accuracy: 0.920
# gamma = 0.001 cross-val mean-accuracy: 0.773
# gamma = 0.01 cross-val mean-accuracy: 0.907
# gamma = 0.1 cross-val mean-accuracy: 0.910
# gamma = 1 cross-val mean-accuracy: 0.923
# gamma = 10 cross-val mean-accuracy: 0.943
# gamma = 100 cross-val mean-accuracy: 0.903

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
param_grid= {
    'C': np.logspace(-5, 5, num=11, base=2),  # C values: 2^-5 to 2^5
    'gamma': np.logspace(-5, 5, num=11, base=2)  # gamma values: 2^-5 to 2^5
}

# Create the GridSearchCV object
grid = GridSearchCV(
    estimator=SVC(kernel='rbf'),  # RBF kernel SVM
    param_grid=param_grid,  # Parameter grid to search
    cv=3,  # 3-fold cross-validation
    scoring='accuracy',  # Use accuracy as the evaluation metric
    verbose=1,  # Print progress
    n_jobs=-1  # Use all available CPU cores
)

# Fit the grid search to the data
grid.fit(X, y)

# Print the best parameters and corresponding accuracy
print("Best parameters found: ", grid.best_params_)
print("Best cross-validation accuracy: {:.3f}".format(grid.best_score_))

# Use the best model to make predictions or visualize the decision boundary
best_model = grid.best_estimator_
nonlinear_plot(X, y, best_model)
# Out:
# Fitting 3 folds for each of 121 candidates, totalling 363 fits
# Best parameters found:  {'C': 8.0, 'gamma': 8.0}
# Best cross-validation accuracy: 0.943
